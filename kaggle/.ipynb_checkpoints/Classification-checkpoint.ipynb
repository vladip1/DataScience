# %% [markdown]
# # Brest Cancer Prediction

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from pandas.api.types import CategoricalDtype
import os

# %%
print(os.getcwd())
os.chdir("C:\\bb\\DataScience\\kaggle")

df = pd.read_csv("train.csv")
# Out:
# C:\bb\DataScience\ML

# %%
df.head()
# Out:
#    id  season  mnth  holiday  weekday  workingday  weathersit      temp  \
# 0   1       1     1        0        6           0           2  0.344167
# 1   2       1     1        0        0           0           2  0.363478
# 2   3       1     1        0        1           1           1  0.196364
# 3   4       1     1        0        2           1           1  0.200000
# 4   5       1     1        0        3           1           1  0.226957
#
#       atemp       hum  windspeed   cnt
# 0  0.363625  0.805833   0.160446   985
# 1  0.353739  0.696087   0.248539   801
# 2  0.189405  0.437273   0.248309  1349
# 3  0.212122  0.590435   0.160296  1562
# 4  0.229270  0.436957   0.186900  1600

# %%
df.describe()
# Out:
#                id      season        mnth     holiday     weekday  workingday  \
# count  365.000000  365.000000  365.000000  365.000000  365.000000  365.000000
# mean   183.000000    2.498630    6.526027    0.027397    3.008219    0.684932
# std    105.510663    1.110946    3.452584    0.163462    2.006155    0.465181
# min      1.000000    1.000000    1.000000    0.000000    0.000000    0.000000
# 25%     92.000000    2.000000    4.000000    0.000000    1.000000    0.000000
# 50%    183.000000    3.000000    7.000000    0.000000    3.000000    1.000000
# 75%    274.000000    3.000000   10.000000    0.000000    5.000000    1.000000
# max    365.000000    4.000000   12.000000    1.000000    6.000000    1.000000
#
#        weathersit        temp       atemp         hum   windspeed          cnt
# count  365.000000  365.000000  365.000000  365.000000  365.000000   365.000000
# mean     1.421918    0.486665    0.466835    0.643665    0.191403  3405.761644
# std      0.571831    0.189596    0.168836    0.148744    0.076890  1378.753666
# min      1.000000    0.059130    0.079070    0.000000    0.022392   431.000000
# 25%      1.000000    0.325000    0.321954    0.538333    0.135583  2132.000000
# 50%      1.000000    0.479167    0.472846    0.647500    0.186900  3740.000000
# 75%      2.000000    0.656667    0.612379    0.742083    0.235075  4586.000000
# max      3.000000    0.849167    0.840896    0.972500    0.507463  6043.000000

# %%
df.isna().sum()
# Out:
# id            0
# season        0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# cnt           0
# dtype: int64

# %%
df2 = df.copy()

# %% [markdown]
# ## k-means

# %%
from sklearn.cluster import KMeans

# %%
wcss = []
for i in range(2, 15):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
    kmeans.fit(df.iloc[:,1:10])
    wcss.append(kmeans.inertia_)

# %%
sns.lineplot(x=range(2, 15), y=wcss)

# %%
kmeans = KMeans(n_clusters=6, init='k-means++', max_iter=300, n_init=10, random_state=0)
kmeans.fit(df.iloc[:,1:10])
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=6, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=0, tol=0.0001, verbose=0)

# %%
df2['cluster'] = kmeans.labels_

# %%
sns.pairplot(df2,hue="cluster")
# Out:
# C:\Users\vladip\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\vladip\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
pd.crosstab(df2.cluster,df2.season)
# Out:
# season    1   2   3   4
# cluster
# 0         5   0  12  51
# 1         0  28  41   0
# 2         0  23  31   0
# 3        34  17   0   0
# 4        45  24   0   0
# 5         6   0  10  38

# %%
from scipy.cluster.hierarchy import dendrogram, linkage, cut_tree, fcluster

# %%
linked = linkage(df.iloc[:,1:10], 'ward')

labelList = range(2, 15)

# %%
dn = dendrogram(linked,color_threshold=120)

# %%
df2['hcluster'] = fcluster(linked, 6, criterion='maxclust')

# %%
pd.crosstab(df2.cluster,df2.hcluster)
# Out:
# hcluster   1   2   3   4   5   6
# cluster
# 0          0   0  46   6  16   0
# 1          0   4   0   0  16  49
# 2          0  19   0   0  35   0
# 3          2  49   0   0   0   0
# 4         44  10   0   0   0  15
# 5          0   0   0  49   1   4

# %%
df2.describe()
# Out:
#                id      season        mnth     holiday     weekday  workingday  \
# count  365.000000  365.000000  365.000000  365.000000  365.000000  365.000000
# mean   183.000000    2.498630    6.526027    0.027397    3.008219    0.684932
# std    105.510663    1.110946    3.452584    0.163462    2.006155    0.465181
# min      1.000000    1.000000    1.000000    0.000000    0.000000    0.000000
# 25%     92.000000    2.000000    4.000000    0.000000    1.000000    0.000000
# 50%    183.000000    3.000000    7.000000    0.000000    3.000000    1.000000
# 75%    274.000000    3.000000   10.000000    0.000000    5.000000    1.000000
# max    365.000000    4.000000   12.000000    1.000000    6.000000    1.000000
#
#        weathersit        temp       atemp         hum   windspeed  \
# count  365.000000  365.000000  365.000000  365.000000  365.000000
# mean     1.421918    0.486665    0.466835    0.643665    0.191403
# std      0.571831    0.189596    0.168836    0.148744    0.076890
# min      1.000000    0.059130    0.079070    0.000000    0.022392
# 25%      1.000000    0.325000    0.321954    0.538333    0.135583
# 50%      1.000000    0.479167    0.472846    0.647500    0.186900
# 75%      2.000000    0.656667    0.612379    0.742083    0.235075
# max      3.000000    0.849167    0.840896    0.972500    0.507463
#
#                cnt     cluster    hcluster
# count   365.000000  365.000000  365.000000
# mean   3405.761644    2.400000    3.605479
# std    1378.753666    1.734903    1.715467
# min     431.000000    0.000000    1.000000
# 25%    2132.000000    1.000000    2.000000
# 50%    3740.000000    2.000000    4.000000
# 75%    4586.000000    4.000000    5.000000
# max    6043.000000    5.000000    6.000000

# %%
df2.head()
# Out:
#    id  season  mnth  holiday  weekday  workingday  weathersit      temp  \
# 0   1       1     1        0        6           0           2  0.344167
# 1   2       1     1        0        0           0           2  0.363478
# 2   3       1     1        0        1           1           1  0.196364
# 3   4       1     1        0        2           1           1  0.200000
# 4   5       1     1        0        3           1           1  0.226957
#
#       atemp       hum  windspeed   cnt  cluster  hcluster
# 0  0.363625  0.805833   0.160446   985        4         1
# 1  0.353739  0.696087   0.248539   801        3         2
# 2  0.189405  0.437273   0.248309  1349        3         2
# 3  0.212122  0.590435   0.160296  1562        3         2
# 4  0.229270  0.436957   0.186900  1600        4         2

# %% [markdown]
# ### Store file in a new csv

# %%
df2.to_csv("train_enriched.csv")
